# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahAdmin/Reviews-Statistics/blob/main/September_%26_October_Interview_Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('September Feedback.csv')

# %%
result1 = df['How satisfied are you with the ease of the application process? - 513b2b55-b818-4f03-bf6f-e82b180c9e60'].value_counts()

# %%
result1.plot(kind='bar',title='How satisfied are you with the ease of the application process?')
# Out:
# <Axes: title={'center': 'How satisfied are you with the ease of the application process?'}, xlabel='How satisfied are you with the ease of the application process? - 513b2b55-b818-4f03-bf6f-e82b180c9e60'>

# %%
result2 = df['How satisfied are you with your interviews with the Hiring Manager and Team? - 605b085d-5bba-4668-babc-17dc8304e06c'].value_counts()

# %%
result2.plot(kind='bar',color='orange',title='How satisfied are you with your interviews with the Hiring Manager and Team?')
# Out:
# <Axes: title={'center': 'How satisfied are you with your interviews with the Hiring Manager and Team?'}, xlabel='How satisfied are you with your interviews with the Hiring Manager and Team? - 605b085d-5bba-4668-babc-17dc8304e06c'>

# %%
result3 = df['How satisfied were you with the interview feedback you received? - e30211c6-d32d-4f89-95fc-dfb91bb47033'].value_counts()

# %%
result3.plot(kind='bar',title='How satisfied were you with the interview feedback you received?')
# Out:
# <Axes: title={'center': 'How satisfied were you with the interview feedback you received?'}, xlabel='How satisfied were you with the interview feedback you received? - e30211c6-d32d-4f89-95fc-dfb91bb47033'>

# %%
result4 = df['How satisfied were you with your Screening call? - de09e7f8-4e8c-498d-9ccb-237788b735d0'].value_counts()

# %%
result4.plot(kind='bar',title='How satisfied were you with your Screening call?')
# Out:
# <Axes: title={'center': 'How satisfied were you with your Screening call?'}, xlabel='How satisfied were you with your Screening call? - de09e7f8-4e8c-498d-9ccb-237788b735d0'>

# %%
df1 = pd.read_csv('October Feedback.csv')

# %%
result5 = df1['How satisfied are you with the ease of the application process? - 513b2b55-b818-4f03-bf6f-e82b180c9e60'].value_counts()

# %%
result5.plot(kind='pie',title='October Feedback - How satisfied are you with the ease of the application process?',autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'October Feedback - How satisfied are you with the ease of the application process?'}, ylabel='count'>

# %%
result6 = df1['How satisfied are you with your interviews with the Hiring Manager and Team? - 605b085d-5bba-4668-babc-17dc8304e06c'].value_counts()

# %%
result6.plot(kind='bar',title='October Feedback - How satisfied are you with your interviews with the Hiring Manager and Team?',color='orange')
# Out:
# <Axes: title={'center': 'October Feedback - How satisfied are you with your interviews with the Hiring Manager and Team?'}, xlabel='How satisfied are you with your interviews with the Hiring Manager and Team? - 605b085d-5bba-4668-babc-17dc8304e06c'>

# %%
result7 = df1['How satisfied were you with the ease of the application process? - 513b2b55-b818-4f03-bf6f-e82b180c9e60']

# %%
result7.plot(kind='bar',title='October Feedback - How satisfied were you with the ease of the application process?',color='orange')
# Out:
# <Axes: title={'center': 'October Feedback - How satisfied were you with the ease of the application process?'}, xlabel='How satisfied were you with the ease of the application process? - 513b2b55-b818-4f03-bf6f-e82b180c9e60'>

# %%
result8 = df1['How satisfied were you with the interview materials you received? - 4158aafc-ce92-4d35-930f-2f5451455a4d'].value_counts()

# %%
result8.plot(kind='pie',title='How satisfied were you with the interview materials you received?',autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'How satisfied were you with the interview materials you received?'}, ylabel='count'>

# %% [markdown]
# These bar and pie charts has the most popular number of our interview feedbacks is '5 - Very Satisfied' because the number of candidates has an excellent peformance for our job interviews to show the number of feedback how satisfied were you had an interview throughout September - October. '4 - Satisfied' has been increasing the number of interview feedback of candidates' interview performance are shown on the bar chart.
