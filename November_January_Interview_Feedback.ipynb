# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahAdmin/Reviews-Statistics/blob/main/November_January_Interview_Feedback.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('November Feedback.csv')

# %%
df.columns
# Out:
# Index(['Applied On', 'Collected On', 'Anonymized Contact ID', 'Posting ID',
#        'Team', 'Department', 'Commitment / Work Type', 'Location', 'Origin',
#        'Sources', 'Current Stage', 'Current Stage ID',
#        'Application Archive Reason', 'Application Archived On',
#        'Application Archived By', 'Survey Id', 'Survey Name',
#        'Survey Location Type', 'Posting Title', 'Posting Owner',
#        'Posting Hiring Manager', 'Candidate Selected Location',
#        'Stage - New lead', 'Stage - Reached out', 'Stage - Responded',
#        'Stage - New applicant', 'Stage - Under review',
#        'Stage - Recruiter Screen', 'Stage - Hiring Manager Screen',
#        'Stage - 1st Round', 'Stage - 2nd Round', 'Stage - Decision',
#        'Stage - Offer',
#        'How satisfied were you with our communication during the recruiting process? - e8c5e9ae-38de-4acb-855c-8d18039b1f5c',
# ...

# %%
resultOne = df['How satisfied were you with our communication during the recruiting process? - e8c5e9ae-38de-4acb-855c-8d18039b1f5c'].value_counts()

# %%
resultOne.plot(kind='pie',legend=False,autopct='%1.1f%%',title='How satisfied were you with our communication during the recruiting process?')
# Out:
# <Axes: title={'center': 'How satisfied were you with our communication during the recruiting process?'}>

# %%
resultTwo = df['How satisfied were you with the interview materials you received? - 4158aafc-ce92-4d35-930f-2f5451455a4d'].value_counts()

# %%
resultTwo.plot(kind='pie',legend=False,autopct='%1.1f%%',title='How satisfied were you with the interview materials you received?')
# Out:
# <Axes: title={'center': 'How satisfied were you with the interview materials you received?'}>

# %%
resultThree = df['How satisfied are you with your interviews with the Hiring Manager and Team? - 605b085d-5bba-4668-babc-17dc8304e06c'].value_counts()

# %%
resultThree.plot(kind='pie',legend=False,autopct='%1.1f%%',title='How satisfied are you with your interviews with the Hiring Manager and Team?')
# Out:
# <Axes: title={'center': 'How satisfied are you with your interviews with the Hiring Manager and Team?'}>

# %%
resultFour = df['How satisfied were you with the interview feedback you received? - e30211c6-d32d-4f89-95fc-dfb91bb47033'].value_counts()

# %%
resultFour.plot(kind='pie',legend=False,autopct='%1.1f%%',title='How satisfied were you with the interview feedback you received?')
# Out:
# <Axes: title={'center': 'How satisfied were you with the interview feedback you received?'}>

# %% [markdown]
# These pie charts shown on the candidates' satisfaction for our inteview feedback in November. The most popular of candidates' sastifaction was '5 - Very Satisfied' because candidates has excellent interview feedback but, the others has different numbers of candidate satsifactions.

# %%
df1 = pd.read_csv('December Feeback.csv')

# %%
df1.columns
# Out:
# Index(['Applied On', 'Collected On', 'Anonymized Contact ID', 'Posting ID',
#        'Team', 'Department', 'Commitment / Work Type', 'Location', 'Origin',
#        'Sources', 'Current Stage', 'Current Stage ID',
#        'Application Archive Reason', 'Application Archived On',
#        'Application Archived By', 'Survey Id', 'Survey Name',
#        'Survey Location Type', 'Posting Title', 'Posting Owner',
#        'Posting Hiring Manager', 'Candidate Selected Location',
#        'Stage - New lead', 'Stage - Reached out', 'Stage - Responded',
#        'Stage - New applicant', 'Stage - Under review',
#        'Stage - Recruiter Screen', 'Stage - Hiring Manager Screen',
#        'Stage - 1st Round', 'Stage - 2nd Round', 'Stage - Decision',
#        'Stage - Offer',
#        'How satisfied are you with the way you were treated? - 05c18285-2750-479f-8afc-d560b66f552c',
#        'What suggestions would you make to improve our interview process? - 21866cc4-7d8f-47da-97df-9efdfcbe083d',
# ...

# %%
resultFive = df['How satisfied are you with the way you were treated? - 05c18285-2750-479f-8afc-d560b66f552c'].value_counts()

# %%
resultFive.plot(kind='pie',legend=False,autopct='%1.1f%%',title='How satisfied are you with the way you were treated?')
# Out:
# <Axes: title={'center': 'How satisfied are you with the way you were treated?'}>

# %%
resultSix = df['Overall, how satisfied were you with your interviewing experience? - 693b0a81-d4e7-40a2-9135-7fc38fa43eaf'].value_counts()

# %%
resultSix.plot(kind='pie',legend=False,autopct='%1.1f%%',title='Overall, how satisfied were you with your interviewing experience?')
# Out:
# <Axes: title={'center': 'Overall, how satisfied were you with your interviewing experience?'}>

# %%
resultSeven = df['How satisfied were you with your Screening call? - de09e7f8-4e8c-498d-9ccb-237788b735d0'].value_counts()

# %%
resultSeven.plot(kind='pie',legend=False,autopct='%1.1f%%',title='How satisfied were you with your Screening call?')
# Out:
# <Axes: title={'center': 'How satisfied were you with your Screening call?'}>

# %%
df2 = pd.read_csv('Jan Feedback.csv')

# %%
df2.columns
# Out:
# Index(['Applied On', 'Collected On', 'Anonymized Contact ID', 'Posting ID',
#        'Team', 'Department', 'Commitment / Work Type', 'Location', 'Origin',
#        'Sources', 'Current Stage', 'Current Stage ID',
#        'Application Archive Reason', 'Application Archived On',
#        'Application Archived By', 'Survey Id', 'Survey Name',
#        'Survey Location Type', 'Posting Title', 'Posting Owner',
#        'Posting Hiring Manager', 'Candidate Selected Location',
#        'Stage - New lead', 'Stage - Reached out', 'Stage - Responded',
#        'Stage - New applicant', 'Stage - Under review',
#        'Stage - Recruiter Screen', 'Stage - Hiring Manager Screen',
#        'Stage - 1st Round', 'Stage - 2nd Round', 'Stage - Decision',
#        'Stage - Offer',
#        'How satisfied were you with the ease of the application process? - 513b2b55-b818-4f03-bf6f-e82b180c9e60',
# ...

# %%
resultEight = df['How satisfied are you with the way you were treated? - 05c18285-2750-479f-8afc-d560b66f552c'].value_counts()

# %%
resultEight.plot(kind='pie',legend=False,autopct='%1.1f%%',title='How satisfied are you with the way you were treated?')
# Out:
# <Axes: title={'center': 'How satisfied are you with the way you were treated?'}>

# %%
resultNine = df['How satisfied are you with your interviews with the Hiring Manager and Team? - 605b085d-5bba-4668-babc-17dc8304e06c'].value_counts()

# %%
resultNine.plot(kind='pie',legend=False,autopct='%1.1f%%',title='How satisfied are you with your interviews with the Hiring Manager and Team?')
# Out:
# <Axes: title={'center': 'How satisfied are you with your interviews with the Hiring Manager and Team?'}>

# %%
resultTen = df['How satisfied were you with our communication during the recruiting process? - e8c5e9ae-38de-4acb-855c-8d18039b1f5c'].value_counts()

# %%
resultTen.plot(kind='pie',legend=False,autopct='%1.1f%%',title='How satisfied were you with our communication during the recruiting process?')
# Out:
# <Axes: title={'center': 'How satisfied were you with our communication during the recruiting process?'}>

# %% [markdown]
# November-January has been increasing the number of candidate satisfaction feebacks for job interviews. '5- Very Satisfied' is a most popular satisfaction feedback than other satisfaction feedbacks.
