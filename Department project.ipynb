# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('September Feedback.csv')

# %%
df.columns
# Out:
# Index(['Applied On', 'Collected On', 'Anonymized Contact ID', 'Posting ID',
#        'Team', 'Department', 'Commitment / Work Type', 'Location', 'Origin',
#        'Sources', 'Current Stage', 'Current Stage ID',
#        'Application Archive Reason', 'Application Archived On',
#        'Application Archived By', 'Survey Id', 'Survey Name',
#        'Survey Location Type', 'Posting Title', 'Posting Owner',
#        'Posting Hiring Manager', 'Candidate Selected Location',
#        'Stage - New lead', 'Stage - Reached out', 'Stage - Responded',
#        'Stage - New applicant', 'Stage - Under review',
#        'Stage - Recruiter Screen', 'Stage - Hiring Manager Screen',
#        'Stage - 1st Round', 'Stage - 2nd Round', 'Stage - Decision',
#        'Stage - Offer',
#        'How satisfied were you with the interview materials you received? - 4158aafc-ce92-4d35-930f-2f5451455a4d',
# ...

# %%
work_departments = df.groupby(['Team','Department'])

# %%
work_departments.first()
# Out:
#                                    Applied On  Collected On  \
# Team                   Department
# Banking & Partnerships Banking          44434         44462
# Client Review          Compliance       44450         44467
# Customer Operations    Sales            44419         44463
# End-Client Onboarding  Compliance       44429         44461
# Growth                 Growth           44404         44462
# New Business - APAC    Sales            44442         44459
# Platform Engineering   Technology       44453         44462
# Software Development   Technology       44454         44466
# Solutions Team         Sales            44445         44461
#
#                                                                Anonymized Contact ID  \
# Team                   Department
# Banking & Partnerships Banking     ad049f372e7e21b8d9a3ee8c1547c2bde70d13ebc7f8a2...
# Client Review          Compliance  95e580b8c3cb5d7a14ce5b44e630a9508bff602b21b829...
# ...
